# %%
import os
import pandas as pd
import numpy as np
import sklearn.decomposition as skl

# %%
def get_game_data(relative=None, stats_filter=None, datasets_dir=None, games_file_name=None, stats_file_name=None):
    """
    Combine game data and regular season statistics to form a DataFrame where each row represents one game from an NCAA
    tournament. Ensure the Team1 and Team2 values are randomly swapped in games_file_name so that the first team is not
    always the higher seed. (Done already for provided data).
    :param relative: If True, use relative change in each category [(Team A - Team B)/avg(Team A, Team B)]. If False,
        use absolute change. Defaults to True.
    :param stats_filter: A function to filter which statistics are kept. Takes a list of stat names and should return
        the filtered list. If None, keep all stats. Defaults to None.
    :param datasets_dir: Name of the directory in cwd containing the CSVs with games_file and stats_file. Defaults to
        'datasets'.
    :param games_file_name: Name of the CSV file containing game info (which teams played in each game).
    :param stats_file_name: Name of the CSV file containing regular season statistics for each team.
    :return: pandas DataFrame containing data for each game detailed in games_file_name. Each row represents one game
        from an NCAA tournament, with statistics in the form Team A - Team B (or relative difference if relative=True).
    """
    #relative = True if relative is None else relative
    datasets_dir = 'datasets' if datasets_dir is None else datasets_dir
    games_file_name = 'NCAA tournament games 2010-2018.csv' if games_file_name is None else games_file_name
    if games_file_name[-4:] != '.csv':
        raise Warning('games_file_name must end in .csv. A CSV file is required.')
    stats_file_name = 'Stats by team and year 2010-2018.csv' if stats_file_name is None else stats_file_name
    if stats_file_name[-4:] != '.csv':
        raise Warning('stats_file_name must end in .csv. A CSV file is required.')
    games_file_path = os.path.join(datasets_dir, games_file_name)
    stats_file_path = os.path.join(datasets_dir, stats_file_name)

    df_games = pd.read_csv(games_file_path, sep=',')
    df_games = df_games.loc[:, ~df_games.columns.str.contains('^Unnamed')]
    df_stats = pd.read_csv(stats_file_path, sep=',')
    df_stats = df_stats.loc[:, ~df_stats.columns.str.contains('^Unnamed')]
    if stats_filter is not None:
        stats = list(df_stats.columns.drop(['School ID', 'Year']))
        stats = stats_filter(stats)
        stats.insert(0, 'School ID')
        df_stats = df_stats[stats]
    else:
        df_stats = df_stats.drop('Year', axis=1)

    df_1 = df_games.join(df_stats.set_index('School ID'), on='Team1 ID')
    df_2 = df_games.join(df_stats.set_index('School ID'), on='Team2 ID')
    df_stats_1 = df_1.loc[:, 'Game Num':].drop('Game Num', axis=1)
    df_stats_2 = df_2.loc[:, 'Game Num':].drop('Game Num', axis=1)
    #if relative:
     #   df_game_data = df_games.join(((df_stats_1 - df_stats_2) / ((df_stats_1 + df_stats_2) / 2)).add_suffix(' Diff'))
    #else:
     #   df_game_data = df_games.join((df_stats_1 - df_stats_2).add_suffix(' Diff'))
    return df_game_data

# %%
# The first step is getting all the data from Game Results and Team Stats in a Pandas DataFrame
game_data = get_game_data(relative=None, stats_filter=None, datasets_dir=None, games_file_name='NCAA tournament games 2010-2018.csv', stats_file_name='Stats by team and year 2010-2018.csv')
game_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-42cfcd66ea17> in <module>
#       1 # The first step is getting all the data from Game Results and Team Stats in a Pandas DataFrame
# ----> 2 game_data = get_game_data(relative=None, stats_filter=None, datasets_dir=None, games_file_name='NCAA tournament games 2010-2018.csv', stats_file_name='Stats by team and year 2010-2018.csv')
#       3 game_data
#
# <ipython-input-11-facfb5a9bc45> in get_game_data(relative, stats_filter, datasets_dir, games_file_name, stats_file_name)
#      46     #else:
#      47      #   df_game_data = df_games.join((df_stats_1 - df_stats_2).add_suffix(' Diff'))
# ---> 48     return df_game_data
#
# NameError: name 'df_game_data' is not defined

# %%
# However, for unsupervised learning, we are attempting to predict tournament seeding based on the team stats for that year
# We need to isolate the stats for the year 2018
game_data_2018 = game_data.loc[game_data['Year']==2018]
game_data_2018
# Out:
#                 Team1 ID                        Team2 ID         Round  \
# 504        Virginia/2018                       UMBC/2018   Round of 64
# 505       Creighton/2018               Kansas State/2018   Round of 64
# 506        Kentucky/2018                   Davidson/2018   Round of 64
# 507         Arizona/2018                    Buffalo/2018   Round of 64
# 508      Miami (FL)/2018             Loyola-Chicago/2018   Round of 64
# 509       Tennessee/2018               Wright State/2018   Round of 64
# 510          Nevada/2018                      Texas/2018   Round of 64
# 511      Cincinnati/2018              Georgia State/2018   Round of 64
# 512            UMBC/2018               Kansas State/2018   Round of 32
# 513        Kentucky/2018                    Buffalo/2018   Round of 32
# 514  Loyola-Chicago/2018                  Tennessee/2018   Round of 32
# 515          Nevada/2018                 Cincinnati/2018   Round of 32
# 516    Kansas State/2018                   Kentucky/2018      Sweet 16
# 517  Loyola-Chicago/2018                     Nevada/2018      Sweet 16
# 518    Kansas State/2018             Loyola-Chicago/2018       Elite 8
# 519          Xavier/2018             Texas Southern/2018   Round of 64
# 520   Florida State/2018                   Missouri/2018   Round of 64
# 521      Ohio State/2018         South Dakota State/2018   Round of 64
# 522         Gonzaga/2018  North Carolina Greensboro/2018   Round of 64
# 523         Houston/2018            San Diego State/2018   Round of 64
# 524        Michigan/2018                    Montana/2018   Round of 64
# 525       Texas A&M/2018                 Providence/2018   Round of 64
# 526  North Carolina/2018                   Lipscomb/2018   Round of 64
# 527   Florida State/2018                     Xavier/2018   Round of 32
# 528         Gonzaga/2018                 Ohio State/2018   Round of 32
# 529        Michigan/2018                    Houston/2018   Round of 32
# 530       Texas A&M/2018             North Carolina/2018   Round of 32
# 531   Florida State/2018                    Gonzaga/2018      Sweet 16
# 532        Michigan/2018                  Texas A&M/2018      Sweet 16
# 533        Michigan/2018              Florida State/2018       Elite 8
# ..                   ...                             ...           ...
# 537        Marshall/2018              Wichita State/2018   Round of 64
# 538         Florida/2018            St. Bonaventure/2018   Round of 64
# 539      Texas Tech/2018          Stephen F. Austin/2018   Round of 64
# 540          Butler/2018                   Arkansas/2018   Round of 64
# 541          Purdue/2018        Cal State Fullerton/2018   Round of 64
# 542       Villanova/2018                    Alabama/2018   Round of 32
# 543   West Virginia/2018                   Marshall/2018   Round of 32
# 544      Texas Tech/2018                    Florida/2018   Round of 32
# 545          Purdue/2018                     Butler/2018   Round of 32
# 512                0.313626                   0.055074
# 513               -0.350042                  -0.153780
# 514                0.402718                   0.109300
# 515               -0.213888                  -0.545501
# 516               -0.197705                  -0.307713
# 517                0.215601                   0.024717
# 518               -0.814033                  -0.603111
# 519                2.000000                   2.000000
# 520                0.660319                   0.280502
# 521               -0.530658                  -0.087504
# 522                0.186216                   0.313290
# 523                0.538482                   0.223369
# 524                0.043287                   0.199476
# 525                0.498303                   0.817989
# 526               -0.165750                   0.531037
# 527               -0.713198                  -0.231653
# 528                0.593684                   0.485168
# 529                0.085925                  -0.089219
# 530               -0.561139                  -0.423825
# 531               -0.806539                  -0.663102
# 532                0.991784                   0.647388
# 533                0.711943                   0.363636
# ..                      ...                        ...
# 537               -0.106809                  -0.720609
# 538               -1.248296                   0.058575
# 539               -0.348780                  -0.142769
# 540               -0.768190                   0.199045
# 541                0.783367                   1.205266
# 542                1.880105                   1.339918
# 543               -0.140839                   0.671797
# 544                1.112644                   0.315083
# 545                1.325536                   0.703895
# 546                0.795248                   0.383342
# 547               -0.279952                  -0.355201
# 548                0.594707                   0.416787
# 549                0.214755                   0.259554
# 550                0.401495                  -0.083097
# 551               -0.423517                  -0.277136
# 552               -0.128777                   0.213721
# 553               -0.319451                  -0.520636
# 554                0.281612                   0.601088
# 555                1.525770                   0.613198
# 556                0.912378                   1.109581
# 557                0.788564                   0.430262
# 558               -0.216085                  -0.014000
# 559               -1.306931                  -1.117913
# 560                0.105294                   0.571385
# 561                0.258141                   0.118449
# 562                1.220720                   1.068760
# 563               -0.062714                  -0.369604
# 564               -0.124586                   0.104071
# 565                0.401393                   0.462978
# 566                0.266674                   0.345424
#
# [63 rows x 37 columns]

# %%
game_data_2018.iloc[0,:]
# Out:
# Team1 ID                     Virginia/2018
# Team2 ID                         UMBC/2018
# Round                          Round of 64
# Round Num                                1
# Team1 result                          loss
# Year                                  2018
# Game Num                                 0
# W-L% Diff                         0.271482
# SOS Diff                            4.9369
# ORtg Diff                        0.0444444
# Drtg Diff                        -0.108626
# FG% Diff                         0.0376523
# Seed Diff                         -1.76471
# WL% * SOS Diff                     3.90126
# 3P% Diff                        -0.0103896
# FT% Diff                          0.154286
# PPG Diff                        -0.0842851
# OPPG Diff                        -0.236735
# APG Diff                         -0.120272
# TOVPG Diff                       -0.355905
# Adjusted WL% Diff                 0.234401
# Adjusted Margin Diff               1.06383
# W-L% Norm Diff                    0.607222
# SOS Norm Diff                      1.42268
# ORtg Norm Diff                    0.727387
# DRtg Norm Diff                     0.70344
# FG% Norm Diff                     0.492761
# Seed Norm Diff                           2
# WL% * SOS Norm Diff                1.37193
# 3P% Norm Diff                   -0.0596742
# FT% Norm Diff                      1.89449
# PPG Norm Diff                      -1.7114
# OPPG Norm Diff                    0.709476
# APG Norm Diff                    -0.471405
# TOVPG Norm Diff                   0.730935
# Adjusted WL% Norm Diff             0.64089
# Adjusted Margin Norm Diff            0.893
# Name: 504, dtype: object
